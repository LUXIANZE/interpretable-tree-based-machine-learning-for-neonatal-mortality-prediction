# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import pydot

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import make_scorer, f1_score, roc_auc_score, precision_score, balanced_accuracy_score, accuracy_score, recall_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE, RFECV

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from catboost import CatBoostClassifier

from collections import deque

# %%
import logging
import sys
from datetime import datetime

# Configure logging
log_filename = f"training_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler(log_filename),
        logging.StreamHandler(sys.stdout)  # optional: show logs live in notebook
    ]
)

logger = logging.getLogger(__name__)
logger.info("==== Test logging setup ====")
# Out:
# 2025-11-05 07:42:01,392 [INFO] ==== Test logging setup ====

# %%
# define constants according to your dataset

DATASET = "sample.csv"
COLUMN_NAME_LOS = "DurationHospStayDay"
COLUMN_NAME_ADMISSION_DATE = "DateAdmission"
COLUMN_NAME_TARGET = "Outcome"

# %%
df = pd.read_csv('../../../../data/' + DATASET, low_memory=False)
df = df.drop(columns=[COLUMN_NAME_LOS])
df.drop(COLUMN_NAME_ADMISSION_DATE, axis=1, inplace=True)

# %%
# Example: binary outcome
X = df.drop(COLUMN_NAME_TARGET, axis=1)
y = df[COLUMN_NAME_TARGET]

# %%
label_encoder = LabelEncoder()
label_mapping = {}
for column in X.columns:
  if X[column].dtype == 'object':
    X[column] = X[column].astype(str)
    X[column] = label_encoder.fit_transform(X[column])
    label_mapping[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

logger.info(label_mapping.keys())
# Out:
# 2025-11-05 07:42:01,437 [INFO] dict_keys(['PtRace_term', 'MaternalDM_term', 'MaternalHT_term', 'MaternalEclampsia_term', 'MaternalChorAm_term', 'MaternalAnemia_term', 'MaternalAbPlacenta_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'AtSteroid_term', 'Intrapartum Antibiotic_term', 'BirthGrowthStatus_term', 'Sex_term', 'BirthFinalModeDeliver_term', 'InitResus_CC_term', 'InitResus_BMV_term', 'InitResus_O2_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_ETV_term', 'RespSpt_HFOVDone', 'RespSpt_ConvVentDone', 'RespSpt_NitrixOxideDone', 'RespSpt_CPAPDone', 'RespSpt_HFNCDone', 'RespSpt_term', 'Surfactant_term', 'SurfactantDuration', 'TPN'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=123
)

# %%
X_test.shape
# Out:
# (231, 43)

# %% [markdown]
# ## Scoring

# %%
scoring = {
    "f1": make_scorer(f1_score, average="binary", pos_label="Dead"),
    "roc_auc": make_scorer(roc_auc_score, needs_proba=True),
    "precision": make_scorer(precision_score, pos_label="Dead"),
    "accuracy": make_scorer(accuracy_score),
    "balanced_accuracy": make_scorer(balanced_accuracy_score),
    "recall": make_scorer(recall_score, pos_label="Dead")
}

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    res = {
        "f1" : f1_score(y_test, y_pred, average="binary", pos_label="Dead"),
        "roc_auc" : roc_auc_score(y_test, y_pred_proba),
        "precision" : precision_score(y_test, y_pred, pos_label="Dead"),
        "accuracy" : accuracy_score(y_test, y_pred),
        "balanced_accuracy" : balanced_accuracy_score(y_test, y_pred),
        "recall" : recall_score(y_test, y_pred, pos_label="Dead")
    }
    return res

# %% [markdown]
# ## Models

# %%
models = [{
        "model": LogisticRegression(max_iter=3000),
        "model_name": "Logistic Regression",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],   # regularization strength
            "model__penalty": ["l1", "l2", "elasticnet"],
            "model__l1_ratio": [0, 0.5, 1]         # only used if elasticnet
        }
    },
    {
        "model": GaussianNB(),
        "model_name": "Gaussian Naive Bayes",
        "hyperparameters": {
            "model__var_smoothing": [1e-9, 1e-8, 1e-7, 1e-6]   # handles numerical stability
        }
    },
    {
        "model": DecisionTreeClassifier(),
        "model_name": "Decision Tree Classifier",
        "hyperparameters": {
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 5, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": [None, "sqrt", "log2"]
        }
    },
    {
        "model": RandomForestClassifier(),
        "model_name": "Random Forest Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": SVC(probability=True),
        "model_name": "Support Vector Classifier",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],
            "model__kernel": ["linear", "rbf", "poly"],
            "model__degree": [2, 3, 4],   # only for poly
            "model__gamma": ["scale", "auto"]
        }
    },
    {
        "model": ExtraTreesClassifier(criterion="entropy",random_state=123),
        "model_name": "Extra Trees Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": KNeighborsClassifier(n_neighbors=3,metric='minkowski',p=2),
        "model_name": "K-Neighbors Classifier",
        "hyperparameters": {
            "model__n_neighbors": [3, 5, 7, 11],
            "model__weights": ["uniform", "distance"],
            "model__metric": ["minkowski", "manhattan"],
            "model__p": [1, 2]   # 1=Manhattan, 2=Euclidean
        }
    },
    {
        "model": GradientBoostingClassifier(),
        "model_name": "Gradient Boosting Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__max_depth": [3, 5, 7],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__subsample": [0.6, 0.8, 1.0],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": CatBoostClassifier(verbose=False),
        "model_name": "CatBoost Classifier",
        "hyperparameters": {
            "model__iterations": [200, 500, 1000],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__depth": [4, 6, 8, 10],
            "model__l2_leaf_reg": [1, 3, 5, 7]
        }
    }]

# %% [markdown]
# ## Tree Processing

# %%
def getRealNodes(nodes):
    real_nodes = []
    for node in nodes:
        if node.get_attributes().get("label") is not None:
            real_nodes.append(node)
    return real_nodes

# %%
def jsonify_nodes(root_node_name, node_list, edge_list):
    """
    Traverses a pydot graph from a root node and returns a list of dictionaries 
    with each node's label and level.

    Args:
        root_node_name (str): The name of the starting (root) node.
        node_list (list): A list of pydot Node objects.
        edge_list (list): A list of pydot Edge objects.

    Returns:
        list: A list of dictionaries, each containing a node's 'label' and 'level'.
    """
    # 1. Build an adjacency list for efficient neighbor lookup
    adj = {node.get_name(): [] for node in node_list}
    for edge in edge_list:
        source = edge.get_source()
        destination = edge.get_destination()
        if source in adj:
            adj[source].append(destination)
    
    # 2. Map node names to their labels
    # Use .get_label() but handle the case where it returns a name, which occurs
    # if no explicit label is set.
    name_to_label_map = {
        node.get_name(): node.get_attributes().get("label")
        if node.get_label() != node.get_name() else node.get_name()
        for node in node_list
    }

    # 3. Prepare data structures for BFS
    queue = deque([(root_node_name, 0)])  # Store tuples of (node_name, level)
    visited = {root_node_name}
    result_list = []

    # 4. Perform the BFS traversal
    while queue:
        current_node_name, level = queue.popleft()
        
        # Get the label from the map we created
        current_label = name_to_label_map.get(current_node_name, current_node_name)
        
        # Add the current node's label and level to the result
        result_list.append({
            "label": current_label,
            "level": level
        })

        # Enqueue all unvisited neighbors
        for neighbor_name in adj.get(current_node_name, []):
            if neighbor_name not in visited:
                visited.add(neighbor_name)
                queue.append((neighbor_name, level + 1))
    
    return result_list

# %%
def tabulate_nodes(json_nodes):
    for node in json_nodes:
        node['label'] = node['label'].split(" ")[0].replace('"', '')
        
    return pd.DataFrame(json_nodes)

test_list = [{
    "label": "BW <= ashdjkasdhk"
}]

tabulate_nodes(test_list)
# Out:
#   label
# 0    BW

# %%
def compute_rankings(tree_count):
    df_list = []
    for i in range(tree_count):
        graph = pydot.graph_from_dot_file(f'Decision paths for Tree {i+1}.dot')
        real_nodes = getRealNodes(graph[0].get_nodes())
        jsonified_nodes = jsonify_nodes(real_nodes[0].get_name(), graph[0].get_nodes(), graph[0].get_edges())
        df_list.append(tabulate_nodes(jsonified_nodes))
        
    aggregated_df = pd.concat(df_list, ignore_index=True)
    return aggregated_df

# %%
def count_by_label(aggregated_df):
    label_counts = (
        aggregated_df
        .groupby(['level', 'label'])
        .size()
        .reset_index(name='count')
        .sort_values(by=['level', 'count'], ascending=[True, False])
    )
    return label_counts

# %%
def getScore(levels:pd.Series):
    max_level = levels.max()
    logger.info(f"Max level: {max_level}")
    scores = []
    for level in levels:
        # The lower the level, the higher the score
        scores.append(max_level - level)
    return scores

# %%
def label_counts_with_score(label_counts):
    label_counts_with_score_df = label_counts.copy()
    label_counts_with_score_df['score'] = (label_counts_with_score_df['count'] * getScore(label_counts_with_score_df['level']))
    label_counts_with_score_df = label_counts_with_score_df.drop(columns=['count', 'level'])
    label_counts_with_score_df = label_counts_with_score_df.groupby(['label'])['score'].sum().reset_index()
    label_counts_with_score_df = label_counts_with_score_df.sort_values(by=['score'], ascending=False)
    return label_counts_with_score_df

# %% [markdown]
# ## Feature name correction

# %%
def rectify_feature_names(ranked_features):
    for i, feature in enumerate(ranked_features):
        if feature == "AtSteroid":
            ranked_features[i] = "AtSteroid Dose_term"
        if feature == "Intrapartum":
            ranked_features[i] = "Intrapartum Antibiotic_term"
    ranked_features.remove("gini")
    return ranked_features

# %% [markdown]
# ## Modeling

# %%
base_estimator = RandomForestClassifier()
base_estimator.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
for i, tree in enumerate(base_estimator.estimators_):
    tree_rules = export_graphviz(tree, out_file=f'Decision paths for Tree {i+1}.dot', feature_names=X_train.columns, class_names=base_estimator.classes_, filled=True)

# %%
aggregated_df = compute_rankings(tree_count=100)
aggregated_df
# Out:
#                            label  level
# 0             BirthAdmissionTemp      0
# 1               RespSpt_HFOVDone      1
# 2                      AtSteroid      1
# 3                             BW      2
# 4     BirthFinalModeDeliver_term      2
# ...                          ...    ...
# 4863                        gini      8
# 4864                        gini      8
# 4865                        gini      8
# 4866                        gini      8
# 4867                        gini      8
#
# [4868 rows x 2 columns]

# %%
count_by_label_df = count_by_label(aggregated_df)
label_counts_with_score_df = label_counts_with_score(count_by_label_df)
label_counts_with_score_df
# Out:
# 2025-11-05 07:42:27,517 [INFO] Max level: 13
#                          label  score
# 42                        gini  17682
# 4                           BW   1785
# 9                           GA   1611
# 25                   MotherAge   1107
# 32            RespSpt_HFNCDone   1074
# 5           BirthAdmissionTemp    979
# 0                    Apgar1Min    961
# 29             RespSpt_CPAPDur    902
# 34             RespSpt_HFOVDur    884
# 1                    Apgar5Min    811
# 33            RespSpt_HFOVDone    802
# 28            RespSpt_CPAPDone    745
# 27                 PtRace_term    670
# 39          SurfactantDuration    634
# 26                      Parity    562
# 6   BirthFinalModeDeliver_term    526
# 10                     Gravida    504
# 38                    Sex_term    493
# 31         RespSpt_ConvVentDur    471
# 14          InitResus_ETV_term    459
# 7       BirthGrowthStatus_term    454
# 40             Surfactant_term    437
# 35     RespSpt_NitrixOxideDone    429
# 36      RespSpt_NitrixOxideDur    413
# 13         InitResus_CPAP_term    394
# 8       BirthMultiplicity_term    378
# 2                    AtSteroid    314
# 41                         TPN    298
# 15           InitResus_O2_term    297
# 30        RespSpt_ConvVentDone    292
# 11          InitResus_BMV_term    249
# 3               AtSteroid_term    199
# 22             MaternalDM_term    193
# 24             MaternalHT_term    136
# 16                 Intrapartum    135
# 18         MaternalAnemia_term    133
# 23      MaternalEclampsia_term    105
# 37                RespSpt_term    100
# 19  MaternalBleedPlacenta_term     85
# 21   MaternalCordProlapse_term     71
# 12           InitResus_CC_term     35
# 20         MaternalChorAm_term     15
# 17     MaternalAbPlacenta_term      8

# %%
ranked_features = label_counts_with_score_df['label'].tolist()
ranked_features = rectify_feature_names(ranked_features)

# %%
feature_group_list = []

for i, feature in enumerate(ranked_features):
    feature_group_list.append(ranked_features[:i+1])

for i, items in enumerate(feature_group_list):
    logger.info(f"Feature Group {i+1}: {items}")
# Out:
# 2025-11-05 07:42:27,542 [INFO] Feature Group 1: ['BW']
# 2025-11-05 07:42:27,544 [INFO] Feature Group 2: ['BW', 'GA']
# 2025-11-05 07:42:27,544 [INFO] Feature Group 3: ['BW', 'GA', 'MotherAge']
# 2025-11-05 07:42:27,545 [INFO] Feature Group 4: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone']
# 2025-11-05 07:42:27,545 [INFO] Feature Group 5: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp']
# 2025-11-05 07:42:27,546 [INFO] Feature Group 6: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min']
# 2025-11-05 07:42:27,546 [INFO] Feature Group 7: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur']
# 2025-11-05 07:42:27,547 [INFO] Feature Group 8: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur']
# 2025-11-05 07:42:27,547 [INFO] Feature Group 9: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min']
# 2025-11-05 07:42:27,548 [INFO] Feature Group 10: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone']
# 2025-11-05 07:42:27,548 [INFO] Feature Group 11: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone']
# 2025-11-05 07:42:27,549 [INFO] Feature Group 12: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term']
# 2025-11-05 07:42:27,549 [INFO] Feature Group 13: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration']
# 2025-11-05 07:42:27,550 [INFO] Feature Group 14: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity']
# 2025-11-05 07:42:27,550 [INFO] Feature Group 15: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term']
# 2025-11-05 07:42:27,550 [INFO] Feature Group 16: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida']
# 2025-11-05 07:42:27,551 [INFO] Feature Group 17: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term']
# 2025-11-05 07:42:27,551 [INFO] Feature Group 18: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur']
# 2025-11-05 07:42:27,551 [INFO] Feature Group 19: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term']
# 2025-11-05 07:42:27,553 [INFO] Feature Group 20: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term']
# 2025-11-05 07:42:27,553 [INFO] Feature Group 21: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term']
# 2025-11-05 07:42:27,553 [INFO] Feature Group 22: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone']
# 2025-11-05 07:42:27,554 [INFO] Feature Group 23: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur']
# 2025-11-05 07:42:27,554 [INFO] Feature Group 24: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term']
# 2025-11-05 07:42:27,555 [INFO] Feature Group 25: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term']
# 2025-11-05 07:42:27,556 [INFO] Feature Group 26: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term']
# 2025-11-05 07:42:27,557 [INFO] Feature Group 27: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN']
# 2025-11-05 07:42:27,557 [INFO] Feature Group 28: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term']
# 2025-11-05 07:42:27,558 [INFO] Feature Group 29: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone']
# 2025-11-05 07:42:27,558 [INFO] Feature Group 30: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term']
# 2025-11-05 07:42:27,558 [INFO] Feature Group 31: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term']
# 2025-11-05 07:42:27,559 [INFO] Feature Group 32: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term']
# 2025-11-05 07:42:27,559 [INFO] Feature Group 33: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term']
# 2025-11-05 07:42:27,559 [INFO] Feature Group 34: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term']
# 2025-11-05 07:42:27,560 [INFO] Feature Group 35: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term']
# 2025-11-05 07:42:27,561 [INFO] Feature Group 36: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term']
# 2025-11-05 07:42:27,561 [INFO] Feature Group 37: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term']
# 2025-11-05 07:42:27,561 [INFO] Feature Group 38: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term']
# 2025-11-05 07:42:27,562 [INFO] Feature Group 39: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term']
# 2025-11-05 07:42:27,562 [INFO] Feature Group 40: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term']
# 2025-11-05 07:42:27,563 [INFO] Feature Group 41: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term', 'MaternalChorAm_term']
# 2025-11-05 07:42:27,563 [INFO] Feature Group 42: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term', 'MaternalChorAm_term', 'MaternalAbPlacenta_term']

# %%
base_estimator = RandomForestClassifier()


# Full pipeline: Feature selection + Oversampling + Classifier
pipeline = ImbPipeline([
    ("ros", SMOTE(random_state=123)),
    ("model", base_estimator)
])

# Hyperparameter grid
param_grid = {
    "model__n_estimators": [100, 200, 500],
    "model__criterion": ["gini", "entropy", "log_loss"],
    "model__max_depth": [None, 10, 20, 50],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__max_features": ["sqrt", "log2", None]
}

# Outer CV (for tuning)
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)

# Define scoring
scorer = make_scorer(roc_auc_score, needs_proba=True)

for i, item in enumerate(feature_group_list):
    logger.info(f"Feature group {i+1}: {item}")
    # Grid search
    search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=outer_cv,
        scoring=scorer,
        n_jobs=-1,
        verbose=0
    )

    search.fit(X_train[item], y_train)

    logger.info(f"Best CV score: {search.best_score_}")
    logger.info(f"Best hyperparameters: {search.best_params_}")
    logger.info(f"Other scores: {evaluate_model(search.best_estimator_, X_train[item], y_train)}")
# Out:
# 2025-11-05 07:42:27,570 [INFO] Feature group 1: ['BW']
# 2025-11-05 07:49:16,559 [INFO] Best CV score: 0.7298458274398868
# 2025-11-05 07:49:16,560 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 10, 'model__n_estimators': 200}
# 2025-11-05 07:49:16,708 [INFO] Other scores: {'f1': 0.43243243243243246, 'roc_auc': 0.9334329349269589, 'precision': 0.2857142857142857, 'accuracy': 0.8438661710037175, 'balanced_accuracy': 0.8647631695440461, 'recall': 0.8888888888888888}
# 2025-11-05 07:49:16,716 [INFO] Feature group 2: ['BW', 'GA']
# 2025-11-05 07:56:30,596 [INFO] Best CV score: 0.8589234441301272
# 2025-11-05 07:56:30,597 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 07:56:30,655 [INFO] Other scores: {'f1': 0.62, 'roc_auc': 0.9663291279327135, 'precision': 0.484375, 'accuracy': 0.929368029739777, 'balanced_accuracy': 0.8976870296591413, 'recall': 0.8611111111111112}
# 2025-11-05 07:56:30,679 [INFO] Feature group 3: ['BW', 'GA', 'MotherAge']
# 2025-11-05 08:02:11,992 [INFO] Best CV score: 0.8341297736916549
# 2025-11-05 08:02:11,993 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 08:02:12,020 [INFO] Other scores: {'f1': 0.6304347826086957, 'roc_auc': 0.980522355024347, 'precision': 0.5178571428571429, 'accuracy': 0.9368029739776952, 'balanced_accuracy': 0.8758853474988934, 'recall': 0.8055555555555556}
# 2025-11-05 08:02:12,024 [INFO] Feature group 4: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone']
# 2025-11-05 08:07:05,543 [INFO] Best CV score: 0.9438016265912307
# 2025-11-05 08:07:05,544 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 08:07:05,609 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:07:05,614 [INFO] Feature group 5: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp']
# 2025-11-05 08:12:20,978 [INFO] Best CV score: 0.9285972418670438
# 2025-11-05 08:12:21,030 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 08:12:21,096 [INFO] Other scores: {'f1': 0.9577464788732395, 'roc_auc': 0.9997786631252767, 'precision': 0.9714285714285714, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9712262062859672, 'recall': 0.9444444444444444}
# 2025-11-05 08:12:21,097 [INFO] Feature group 6: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min']
# 2025-11-05 08:18:13,714 [INFO] Best CV score: 0.923518387553041
# 2025-11-05 08:18:13,715 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 08:18:13,950 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9998893315626383, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 08:18:13,985 [INFO] Feature group 7: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur']
# 2025-11-05 08:24:54,268 [INFO] Best CV score: 0.9280116690240453
# 2025-11-05 08:24:54,269 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 08:24:54,363 [INFO] Other scores: {'f1': 0.9315068493150684, 'roc_auc': 0.994411243913236, 'precision': 0.918918918918919, 'accuracy': 0.9907063197026023, 'balanced_accuracy': 0.9692341744134573, 'recall': 0.9444444444444444}
# 2025-11-05 08:24:54,364 [INFO] Feature group 8: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur']
# 2025-11-05 08:30:48,563 [INFO] Best CV score: 0.9833939179632247
# 2025-11-05 08:30:48,564 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:30:48,595 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:30:48,601 [INFO] Feature group 9: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min']
# 2025-11-05 08:36:57,590 [INFO] Best CV score: 0.9818196605374823
# 2025-11-05 08:36:57,591 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:36:57,635 [INFO] Other scores: {'f1': 0.927536231884058, 'roc_auc': 0.9994466578131918, 'precision': 0.9696969696969697, 'accuracy': 0.9907063197026023, 'balanced_accuracy': 0.9434484285081894, 'recall': 0.8888888888888888}
# 2025-11-05 08:36:57,637 [INFO] Feature group 10: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone']
# 2025-11-05 08:42:59,082 [INFO] Best CV score: 0.9814483734087694
# 2025-11-05 08:42:59,083 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 08:42:59,137 [INFO] Other scores: {'f1': 0.9428571428571428, 'roc_auc': 0.9990593182824259, 'precision': 0.9705882352941176, 'accuracy': 0.9925650557620818, 'balanced_accuracy': 0.9573373173970783, 'recall': 0.9166666666666666}
# 2025-11-05 08:42:59,143 [INFO] Feature group 11: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone']
# 2025-11-05 08:48:57,707 [INFO] Best CV score: 0.9826269448373409
# 2025-11-05 08:48:57,708 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 08:48:57,802 [INFO] Other scores: {'f1': 0.9565217391304348, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9583333333333333, 'recall': 0.9166666666666666}
# 2025-11-05 08:48:57,803 [INFO] Feature group 12: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term']
# 2025-11-05 08:55:04,379 [INFO] Best CV score: 0.9864183168316831
# 2025-11-05 08:55:04,381 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 08:55:04,483 [INFO] Other scores: {'f1': 0.9565217391304348, 'roc_auc': 0.9998893315626383, 'precision': 1.0, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9583333333333333, 'recall': 0.9166666666666666}
# 2025-11-05 08:55:04,485 [INFO] Feature group 13: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration']
# 2025-11-05 09:01:00,046 [INFO] Best CV score: 0.987255657708628
# 2025-11-05 09:01:00,047 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:01:00,105 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:01:00,111 [INFO] Feature group 14: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity']
# 2025-11-05 09:07:08,639 [INFO] Best CV score: 0.9864070014144272
# 2025-11-05 09:07:08,646 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:07:08,703 [INFO] Other scores: {'f1': 0.9577464788732395, 'roc_auc': 0.9997786631252766, 'precision': 0.9714285714285714, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9712262062859672, 'recall': 0.9444444444444444}
# 2025-11-05 09:07:08,712 [INFO] Feature group 15: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term']
# 2025-11-05 09:13:28,036 [INFO] Best CV score: 0.9853327439886845
# 2025-11-05 09:13:28,038 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 09:13:28,172 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 09:13:28,179 [INFO] Feature group 16: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida']
# 2025-11-05 09:20:03,908 [INFO] Best CV score: 0.9873412305516267
# 2025-11-05 09:20:03,910 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:20:04,020 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 09:20:04,021 [INFO] Feature group 17: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term']
# 2025-11-05 09:26:33,605 [INFO] Best CV score: 0.9854070014144272
# 2025-11-05 09:26:33,606 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:26:33,656 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 09:26:33,699 [INFO] Feature group 18: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur']
# 2025-11-05 09:33:25,355 [INFO] Best CV score: 0.9898111739745403
# 2025-11-05 09:33:25,356 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:33:25,424 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 09:33:25,459 [INFO] Feature group 19: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term']
# 2025-11-05 09:39:59,222 [INFO] Best CV score: 0.9904041725601133
# 2025-11-05 09:39:59,258 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:39:59,288 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:39:59,289 [INFO] Feature group 20: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term']
# 2025-11-05 09:46:48,787 [INFO] Best CV score: 0.9894756011315418
# 2025-11-05 09:46:48,789 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 09:46:48,886 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 09:46:48,887 [INFO] Feature group 21: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term']
# 2025-11-05 09:53:21,976 [INFO] Best CV score: 0.9895113154172559
# 2025-11-05 09:53:22,044 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 09:53:22,210 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 09:53:22,220 [INFO] Feature group 22: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone']
# 2025-11-05 10:00:06,362 [INFO] Best CV score: 0.9910413719943423
# 2025-11-05 10:00:06,364 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:00:06,388 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:00:06,389 [INFO] Feature group 23: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur']
# 2025-11-05 10:06:47,082 [INFO] Best CV score: 0.9921870579915135
# 2025-11-05 10:06:47,084 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 200}
# 2025-11-05 10:06:47,159 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9999446657813192, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 10:06:47,166 [INFO] Feature group 24: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term']
# 2025-11-05 10:13:35,884 [INFO] Best CV score: 0.9919135431400283
# 2025-11-05 10:13:35,884 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 10:13:35,960 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:13:35,980 [INFO] Feature group 25: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term']
# 2025-11-05 10:20:27,177 [INFO] Best CV score: 0.9915742574257426
# 2025-11-05 10:20:27,182 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:20:27,203 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 10:20:27,204 [INFO] Feature group 26: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term']
# 2025-11-05 10:27:25,384 [INFO] Best CV score: 0.9916099717114569
# 2025-11-05 10:27:25,385 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 10:27:25,531 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 10:27:25,536 [INFO] Feature group 27: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN']
# 2025-11-05 10:34:18,989 [INFO] Best CV score: 0.9919013437057991
# 2025-11-05 10:34:18,991 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:34:19,034 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:34:19,067 [INFO] Feature group 28: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term']
# 2025-11-05 10:41:15,882 [INFO] Best CV score: 0.9914314002828855
# 2025-11-05 10:41:15,886 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:41:15,917 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 0.9999446657813191, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 10:41:15,918 [INFO] Feature group 29: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone']
# 2025-11-05 10:46:01,524 [INFO] Best CV score: 0.9918585572842998
# 2025-11-05 10:46:01,532 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 500}
# 2025-11-05 10:46:01,628 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:46:01,630 [INFO] Feature group 30: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term']
# 2025-11-05 10:51:07,296 [INFO] Best CV score: 0.9922613154172562
# 2025-11-05 10:51:07,300 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:51:07,333 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 10:51:07,335 [INFO] Feature group 31: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term']
# 2025-11-05 10:55:58,311 [INFO] Best CV score: 0.9920728429985856
# 2025-11-05 10:55:58,311 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 10:55:58,337 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:55:58,337 [INFO] Feature group 32: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term']
# 2025-11-05 11:01:07,205 [INFO] Best CV score: 0.9923764144271571
# 2025-11-05 11:01:07,207 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 11:01:07,256 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:01:07,269 [INFO] Feature group 33: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term']
# 2025-11-05 11:06:08,048 [INFO] Best CV score: 0.9918270862800564
# 2025-11-05 11:06:08,049 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 11:06:08,085 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:06:08,086 [INFO] Feature group 34: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term']
# 2025-11-05 11:11:14,443 [INFO] Best CV score: 0.9930442008486564
# 2025-11-05 11:11:14,460 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 11:11:14,483 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 11:11:14,490 [INFO] Feature group 35: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term']
# 2025-11-05 11:16:29,472 [INFO] Best CV score: 0.9918270862800564
# 2025-11-05 11:16:29,520 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 500}
# 2025-11-05 11:16:29,656 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:16:29,657 [INFO] Feature group 36: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term']
# 2025-11-05 11:21:28,579 [INFO] Best CV score: 0.9921128005657709
# 2025-11-05 11:21:28,579 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 11:21:28,612 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 0.9999999999999999, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 11:21:28,613 [INFO] Feature group 37: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term']
# 2025-11-05 11:26:44,789 [INFO] Best CV score: 0.9911128005657709
# 2025-11-05 11:26:44,790 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 11:26:44,814 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 11:26:44,815 [INFO] Feature group 38: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term']
# 2025-11-05 11:31:50,948 [INFO] Best CV score: 0.9929727722772277
# 2025-11-05 11:31:51,029 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 11:31:51,054 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:31:51,055 [INFO] Feature group 39: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term']
# 2025-11-05 11:36:57,324 [INFO] Best CV score: 0.9922885431400281
# 2025-11-05 11:36:57,325 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# 2025-11-05 11:36:57,353 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 11:36:57,355 [INFO] Feature group 40: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term']
# 2025-11-05 11:42:16,263 [INFO] Best CV score: 0.9918064002828855
# 2025-11-05 11:42:16,265 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 11:42:16,300 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:42:16,301 [INFO] Feature group 41: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term', 'MaternalChorAm_term']
# 2025-11-05 11:47:12,471 [INFO] Best CV score: 0.9915385431400283
# 2025-11-05 11:47:12,471 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 11:47:12,504 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:47:12,505 [INFO] Feature group 42: ['BW', 'GA', 'MotherAge', 'RespSpt_HFNCDone', 'BirthAdmissionTemp', 'Apgar1Min', 'RespSpt_CPAPDur', 'RespSpt_HFOVDur', 'Apgar5Min', 'RespSpt_HFOVDone', 'RespSpt_CPAPDone', 'PtRace_term', 'SurfactantDuration', 'Parity', 'BirthFinalModeDeliver_term', 'Gravida', 'Sex_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'BirthGrowthStatus_term', 'Surfactant_term', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'InitResus_CPAP_term', 'BirthMultiplicity_term', 'AtSteroid Dose_term', 'TPN', 'InitResus_O2_term', 'RespSpt_ConvVentDone', 'InitResus_BMV_term', 'AtSteroid_term', 'MaternalDM_term', 'MaternalHT_term', 'Intrapartum Antibiotic_term', 'MaternalAnemia_term', 'MaternalEclampsia_term', 'RespSpt_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'InitResus_CC_term', 'MaternalChorAm_term', 'MaternalAbPlacenta_term']
# 2025-11-05 11:52:26,938 [INFO] Best CV score: 0.9917171145685997
# 2025-11-05 11:52:26,939 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 11:52:26,970 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
