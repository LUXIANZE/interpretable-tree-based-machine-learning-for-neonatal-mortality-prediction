# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import pydot

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import make_scorer, f1_score, roc_auc_score, precision_score, balanced_accuracy_score, accuracy_score, recall_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE, RFECV

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from catboost import CatBoostClassifier

from collections import deque

# %%
import logging
import sys
from datetime import datetime

# Configure logging
log_filename = f"training_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler(log_filename),
        logging.StreamHandler(sys.stdout)  # optional: show logs live in notebook
    ]
)

logger = logging.getLogger(__name__)
logger.info("==== Test logging setup ====")
# Out:
# 2025-11-05 07:42:03,279 [INFO] ==== Test logging setup ====

# %%
# define constants according to your dataset

DATASET = "sample.csv"
COLUMN_NAME_LOS = "DurationHospStayDay"
COLUMN_NAME_ADMISSION_DATE = "DateAdmission"
COLUMN_NAME_TARGET = "Outcome"

# %%
df = pd.read_csv('../../../../data/' + DATASET, low_memory=False)
df = df.drop(columns=[COLUMN_NAME_LOS])
df.drop(COLUMN_NAME_ADMISSION_DATE, axis=1, inplace=True)

# %%
# Example: binary outcome
X = df.drop(COLUMN_NAME_TARGET, axis=1)
y = df[COLUMN_NAME_TARGET]

# %%
label_encoder = LabelEncoder()
label_mapping = {}
for column in X.columns:
  if X[column].dtype == 'object':
    X[column] = X[column].astype(str)
    X[column] = label_encoder.fit_transform(X[column])
    label_mapping[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

logger.info(label_mapping.keys())
# Out:
# 2025-11-05 07:42:03,309 [INFO] dict_keys(['PtRace_term', 'MaternalDM_term', 'MaternalHT_term', 'MaternalEclampsia_term', 'MaternalChorAm_term', 'MaternalAnemia_term', 'MaternalAbPlacenta_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'AtSteroid_term', 'Intrapartum Antibiotic_term', 'BirthGrowthStatus_term', 'Sex_term', 'BirthFinalModeDeliver_term', 'InitResus_CC_term', 'InitResus_BMV_term', 'InitResus_O2_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_ETV_term', 'RespSpt_HFOVDone', 'RespSpt_ConvVentDone', 'RespSpt_NitrixOxideDone', 'RespSpt_CPAPDone', 'RespSpt_HFNCDone', 'RespSpt_term', 'Surfactant_term', 'SurfactantDuration', 'TPN'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=123
)

# %% [markdown]
# ## Scoring

# %%
scoring = {
    "f1": make_scorer(f1_score, average="binary", pos_label="Dead"),
    "roc_auc": make_scorer(roc_auc_score, needs_proba=True),
    "precision": make_scorer(precision_score, pos_label="Dead"),
    "accuracy": make_scorer(accuracy_score),
    "balanced_accuracy": make_scorer(balanced_accuracy_score),
    "recall": make_scorer(recall_score, pos_label="Dead")
}

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    res = {
        "f1" : f1_score(y_test, y_pred, average="binary", pos_label="Dead"),
        "roc_auc" : roc_auc_score(y_test, y_pred_proba),
        "precision" : precision_score(y_test, y_pred, pos_label="Dead"),
        "accuracy" : accuracy_score(y_test, y_pred),
        "balanced_accuracy" : balanced_accuracy_score(y_test, y_pred),
        "recall" : recall_score(y_test, y_pred, pos_label="Dead")
    }
    return res

# %% [markdown]
# ## Models

# %%
models = [{
        "model": LogisticRegression(max_iter=3000),
        "model_name": "Logistic Regression",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],   # regularization strength
            "model__penalty": ["l1", "l2", "elasticnet"],
            "model__l1_ratio": [0, 0.5, 1]         # only used if elasticnet
        }
    },
    {
        "model": GaussianNB(),
        "model_name": "Gaussian Naive Bayes",
        "hyperparameters": {
            "model__var_smoothing": [1e-9, 1e-8, 1e-7, 1e-6]   # handles numerical stability
        }
    },
    {
        "model": DecisionTreeClassifier(),
        "model_name": "Decision Tree Classifier",
        "hyperparameters": {
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 5, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": [None, "sqrt", "log2"]
        }
    },
    {
        "model": RandomForestClassifier(),
        "model_name": "Random Forest Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": SVC(probability=True),
        "model_name": "Support Vector Classifier",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],
            "model__kernel": ["linear", "rbf", "poly"],
            "model__degree": [2, 3, 4],   # only for poly
            "model__gamma": ["scale", "auto"]
        }
    },
    {
        "model": ExtraTreesClassifier(criterion="entropy",random_state=123),
        "model_name": "Extra Trees Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": KNeighborsClassifier(n_neighbors=3,metric='minkowski',p=2),
        "model_name": "K-Neighbors Classifier",
        "hyperparameters": {
            "model__n_neighbors": [3, 5, 7, 11],
            "model__weights": ["uniform", "distance"],
            "model__metric": ["minkowski", "manhattan"],
            "model__p": [1, 2]   # 1=Manhattan, 2=Euclidean
        }
    },
    {
        "model": GradientBoostingClassifier(),
        "model_name": "Gradient Boosting Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__max_depth": [3, 5, 7],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__subsample": [0.6, 0.8, 1.0],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": CatBoostClassifier(verbose=False),
        "model_name": "CatBoost Classifier",
        "hyperparameters": {
            "model__iterations": [200, 500, 1000],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__depth": [4, 6, 8, 10],
            "model__l2_leaf_reg": [1, 3, 5, 7]
        }
    }]

# %% [markdown]
# ## Tree Processing

# %%
def getRealNodes(nodes):
    real_nodes = []
    for node in nodes:
        if node.get_attributes().get("label") is not None:
            real_nodes.append(node)
    return real_nodes

# %%
def jsonify_nodes(root_node_name, node_list, edge_list):
    """
    Traverses a pydot graph from a root node and returns a list of dictionaries 
    with each node's label and level.

    Args:
        root_node_name (str): The name of the starting (root) node.
        node_list (list): A list of pydot Node objects.
        edge_list (list): A list of pydot Edge objects.

    Returns:
        list: A list of dictionaries, each containing a node's 'label' and 'level'.
    """
    # 1. Build an adjacency list for efficient neighbor lookup
    adj = {node.get_name(): [] for node in node_list}
    for edge in edge_list:
        source = edge.get_source()
        destination = edge.get_destination()
        if source in adj:
            adj[source].append(destination)
    
    # 2. Map node names to their labels
    # Use .get_label() but handle the case where it returns a name, which occurs
    # if no explicit label is set.
    name_to_label_map = {
        node.get_name(): node.get_attributes().get("label")
        if node.get_label() != node.get_name() else node.get_name()
        for node in node_list
    }

    # 3. Prepare data structures for BFS
    queue = deque([(root_node_name, 0)])  # Store tuples of (node_name, level)
    visited = {root_node_name}
    result_list = []

    # 4. Perform the BFS traversal
    while queue:
        current_node_name, level = queue.popleft()
        
        # Get the label from the map we created
        current_label = name_to_label_map.get(current_node_name, current_node_name)
        
        # Add the current node's label and level to the result
        result_list.append({
            "label": current_label,
            "level": level
        })

        # Enqueue all unvisited neighbors
        for neighbor_name in adj.get(current_node_name, []):
            if neighbor_name not in visited:
                visited.add(neighbor_name)
                queue.append((neighbor_name, level + 1))
    
    return result_list

# %%
def tabulate_nodes(json_nodes):
    for node in json_nodes:
        node['label'] = node['label'].split(" ")[0].replace('"', '')
        
    return pd.DataFrame(json_nodes)

test_list = [{
    "label": "BW <= ashdjkasdhk"
}]

tabulate_nodes(test_list)
# Out:
#   label
# 0    BW

# %%
def compute_rankings(tree_count):
    df_list = []
    for i in range(tree_count):
        graph = pydot.graph_from_dot_file(f'Decision paths for Tree {i+1}.dot')
        real_nodes = getRealNodes(graph[0].get_nodes())
        jsonified_nodes = jsonify_nodes(real_nodes[0].get_name(), graph[0].get_nodes(), graph[0].get_edges())
        df_list.append(tabulate_nodes(jsonified_nodes))
        
    aggregated_df = pd.concat(df_list, ignore_index=True)
    return aggregated_df

# %%
def count_by_label(aggregated_df):
    label_counts = (
        aggregated_df
        .groupby(['level', 'label'])
        .size()
        .reset_index(name='count')
        .sort_values(by=['level', 'count'], ascending=[True, False])
    )
    return label_counts

# %%
def getScore(levels:pd.Series):
    max_level = levels.max()
    logger.info(f"Max level: {max_level}")
    scores = []
    for level in levels:
        # The lower the level, the higher the score
        scores.append(max_level - level)
    return scores

# %%
def label_counts_with_score(label_counts):
    label_counts_with_score_df = label_counts.copy()
    label_counts_with_score_df['score'] = (label_counts_with_score_df['count'] * getScore(label_counts_with_score_df['level']))
    label_counts_with_score_df = label_counts_with_score_df.drop(columns=['count', 'level'])
    label_counts_with_score_df = label_counts_with_score_df.groupby(['label'])['score'].sum().reset_index()
    label_counts_with_score_df = label_counts_with_score_df.sort_values(by=['score'], ascending=False)
    return label_counts_with_score_df

# %% [markdown]
# ## Feature name correction

# %%
def rectify_feature_names(ranked_features):
    for i, feature in enumerate(ranked_features):
        if feature == "AtSteroid":
            ranked_features[i] = "AtSteroid Dose_term"
        if feature == "Intrapartum":
            ranked_features[i] = "Intrapartum Antibiotic_term"
    ranked_features.remove("friedman_mse")
    return ranked_features

# %% [markdown]
# ## Modeling

# %%
base_estimator = GradientBoostingClassifier()
base_estimator.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
for i, estimator_array in enumerate(base_estimator.estimators_):
    # In GradientBoostingClassifier, estimators_ is a 2D array where each row
    # represents a stage and each column represents a class (for multi-class)
    # For binary classification, there is only one tree per stage.
    tree = estimator_array[0] # Get the first (and only) tree for binary classification

    # You can use export_text to get a text-based representation of the tree rules
    tree_rules = export_graphviz(tree, out_file=f'Decision paths for Tree {i+1}.dot', feature_names=X_train.columns, class_names=base_estimator.classes_, filled=True)

# %%
aggregated_df = compute_rankings(tree_count=100)
aggregated_df
# Out:
#                         label  level
# 0            RespSpt_HFOVDone      0
# 1                          BW      1
# 2            RespSpt_HFNCDone      1
# 3            RespSpt_HFNCDone      2
# 4     RespSpt_NitrixOxideDone      2
# ...                       ...    ...
# 1349             friedman_mse      3
# 1350             friedman_mse      3
# 1351             friedman_mse      3
# 1352             friedman_mse      3
# 1353             friedman_mse      3
#
# [1354 rows x 2 columns]

# %%
count_by_label_df = count_by_label(aggregated_df)
label_counts_with_score_df = label_counts_with_score(count_by_label_df)
label_counts_with_score_df
# Out:
# 2025-11-05 07:42:08,872 [INFO] Max level: 3
#                          label  score
# 3                           BW    122
# 8                           GA    120
# 24            RespSpt_HFNCDone    109
# 26             RespSpt_HFOVDur     92
# 25            RespSpt_HFOVDone     91
# 0                    Apgar1Min     73
# 33                friedman_mse     73
# 17                   MotherAge     60
# 27     RespSpt_NitrixOxideDone     50
# 28      RespSpt_NitrixOxideDur     43
# 19                 PtRace_term     42
# 4           BirthAdmissionTemp     37
# 31             Surfactant_term     26
# 20            RespSpt_CPAPDone     26
# 29                    Sex_term     24
# 30          SurfactantDuration     20
# 21             RespSpt_CPAPDur     14
# 1                    Apgar5Min     13
# 7       BirthMultiplicity_term     11
# 23         RespSpt_ConvVentDur     10
# 14          InitResus_ETV_term      9
# 22        RespSpt_ConvVentDone      6
# 32                         TPN      6
# 15           InitResus_O2_term      5
# 18                      Parity      4
# 6       BirthGrowthStatus_term      3
# 13         InitResus_CPAP_term      3
# 10        InitResus_Adren_term      2
# 12           InitResus_CC_term      1
# 2                    AtSteroid      1
# 11          InitResus_BMV_term      1
# 16         MaternalAnemia_term      1
# 9                      Gravida      1
# 5   BirthFinalModeDeliver_term      1

# %%
ranked_features = label_counts_with_score_df['label'].tolist()
ranked_features = rectify_feature_names(ranked_features)

# %%
feature_group_list = []

for i, feature in enumerate(ranked_features):
    feature_group_list.append(ranked_features[:i+1])

for i, items in enumerate(feature_group_list):
    logger.info(f"Feature Group {i+1}: {items}")
# Out:
# 2025-11-05 07:42:08,910 [INFO] Feature Group 1: ['BW']
# 2025-11-05 07:42:08,915 [INFO] Feature Group 2: ['BW', 'GA']
# 2025-11-05 07:42:08,917 [INFO] Feature Group 3: ['BW', 'GA', 'RespSpt_HFNCDone']
# 2025-11-05 07:42:08,917 [INFO] Feature Group 4: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur']
# 2025-11-05 07:42:08,919 [INFO] Feature Group 5: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone']
# 2025-11-05 07:42:08,919 [INFO] Feature Group 6: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min']
# 2025-11-05 07:42:08,919 [INFO] Feature Group 7: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge']
# 2025-11-05 07:42:08,920 [INFO] Feature Group 8: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone']
# 2025-11-05 07:42:08,920 [INFO] Feature Group 9: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur']
# 2025-11-05 07:42:08,920 [INFO] Feature Group 10: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term']
# 2025-11-05 07:42:08,921 [INFO] Feature Group 11: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp']
# 2025-11-05 07:42:08,922 [INFO] Feature Group 12: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term']
# 2025-11-05 07:42:08,923 [INFO] Feature Group 13: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone']
# 2025-11-05 07:42:08,923 [INFO] Feature Group 14: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term']
# 2025-11-05 07:42:08,924 [INFO] Feature Group 15: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration']
# 2025-11-05 07:42:08,924 [INFO] Feature Group 16: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur']
# 2025-11-05 07:42:08,924 [INFO] Feature Group 17: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min']
# 2025-11-05 07:42:08,925 [INFO] Feature Group 18: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term']
# 2025-11-05 07:42:08,925 [INFO] Feature Group 19: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur']
# 2025-11-05 07:42:08,930 [INFO] Feature Group 20: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term']
# 2025-11-05 07:42:08,935 [INFO] Feature Group 21: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone']
# 2025-11-05 07:42:08,939 [INFO] Feature Group 22: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN']
# 2025-11-05 07:42:08,940 [INFO] Feature Group 23: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term']
# 2025-11-05 07:42:08,941 [INFO] Feature Group 24: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity']
# 2025-11-05 07:42:08,942 [INFO] Feature Group 25: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term']
# 2025-11-05 07:42:08,943 [INFO] Feature Group 26: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term']
# 2025-11-05 07:42:08,944 [INFO] Feature Group 27: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term']
# 2025-11-05 07:42:08,946 [INFO] Feature Group 28: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term']
# 2025-11-05 07:42:08,947 [INFO] Feature Group 29: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term']
# 2025-11-05 07:42:08,950 [INFO] Feature Group 30: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term']
# 2025-11-05 07:42:08,951 [INFO] Feature Group 31: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term']
# 2025-11-05 07:42:08,952 [INFO] Feature Group 32: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term', 'Gravida']
# 2025-11-05 07:42:08,953 [INFO] Feature Group 33: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term', 'Gravida', 'BirthFinalModeDeliver_term']

# %%
base_estimator = GradientBoostingClassifier()


# Full pipeline: Feature selection + Oversampling + Classifier
pipeline = ImbPipeline([
    ("ros", SMOTE(random_state=123)),
    ("model", base_estimator)
])

# Hyperparameter grid
param_grid = {
    "model__n_estimators": [100, 200, 500],
    "model__learning_rate": [0.01, 0.05, 0.1],
    "model__max_depth": [3, 5, 7],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__subsample": [0.6, 0.8, 1.0],
    "model__max_features": ["sqrt", "log2", None]
}

# Outer CV (for tuning)
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)

# Define scoring
scorer = make_scorer(roc_auc_score, needs_proba=True)

for i, item in enumerate(feature_group_list):
    logger.info(f"Feature group {i+1}: {item}")
    # Grid search
    search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=outer_cv,
        scoring=scorer,
        n_jobs=-1,
        verbose=0
    )

    search.fit(X_train[item], y_train)

    logger.info(f"Best CV score: {search.best_score_}")
    logger.info(f"Best hyperparameters: {search.best_params_}")
    logger.info(f"Other scores: {evaluate_model(search.best_estimator_, X_train[item], y_train)}")
# Out:
# 2025-11-05 07:42:09,041 [INFO] Feature group 1: ['BW']
# 2025-11-05 07:53:12,065 [INFO] Best CV score: 0.7743576732673267
# 2025-11-05 07:53:12,066 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 3, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200, 'model__subsample': 0.8}
# 2025-11-05 07:53:12,082 [INFO] Other scores: {'f1': 0.35897435897435903, 'roc_auc': 0.8966633466135457, 'precision': 0.23333333333333334, 'accuracy': 0.8141263940520446, 'balanced_accuracy': 0.7972554227534308, 'recall': 0.7777777777777778}
# 2025-11-05 07:53:12,100 [INFO] Feature group 2: ['BW', 'GA']
# 2025-11-05 08:03:56,188 [INFO] Best CV score: 0.8681974893917964
# 2025-11-05 08:03:56,189 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.6}
# 2025-11-05 08:03:56,207 [INFO] Other scores: {'f1': 0.594059405940594, 'roc_auc': 0.9560646303674192, 'precision': 0.46153846153846156, 'accuracy': 0.9237918215613383, 'balanced_accuracy': 0.8818061088977424, 'recall': 0.8333333333333334}
# 2025-11-05 08:03:56,207 [INFO] Feature group 3: ['BW', 'GA', 'RespSpt_HFNCDone']
# 2025-11-05 08:13:13,746 [INFO] Best CV score: 0.9409600424328147
# 2025-11-05 08:13:13,747 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 08:13:13,767 [INFO] Other scores: {'f1': 0.9722222222222222, 'roc_auc': 0.9998893315626383, 'precision': 0.9722222222222222, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9851150951748562, 'recall': 0.9722222222222222}
# 2025-11-05 08:13:13,767 [INFO] Feature group 4: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur']
# 2025-11-05 08:24:11,096 [INFO] Best CV score: 0.9934163719943424
# 2025-11-05 08:24:11,117 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200, 'model__subsample': 1.0}
# 2025-11-05 08:24:11,207 [INFO] Other scores: {'f1': 0.9577464788732395, 'roc_auc': 0.9997233289065958, 'precision': 0.9714285714285714, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9712262062859672, 'recall': 0.9444444444444444}
# 2025-11-05 08:24:11,208 [INFO] Feature group 5: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone']
# 2025-11-05 08:35:10,279 [INFO] Best CV score: 0.9920583451202264
# 2025-11-05 08:35:10,280 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 1.0}
# 2025-11-05 08:35:10,310 [INFO] Other scores: {'f1': 0.9577464788732395, 'roc_auc': 0.9996679946879149, 'precision': 0.9714285714285714, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9712262062859672, 'recall': 0.9444444444444444}
# 2025-11-05 08:35:10,311 [INFO] Feature group 6: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min']
# 2025-11-05 08:46:43,532 [INFO] Best CV score: 0.9806683168316832
# 2025-11-05 08:46:43,533 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 0.8}
# 2025-11-05 08:46:43,621 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:46:43,651 [INFO] Feature group 7: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge']
# 2025-11-05 08:58:33,465 [INFO] Best CV score: 0.9863571428571429
# 2025-11-05 08:58:33,466 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 500, 'model__subsample': 1.0}
# 2025-11-05 08:58:33,498 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:58:33,522 [INFO] Feature group 8: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone']
# 2025-11-05 09:10:47,914 [INFO] Best CV score: 0.985898514851485
# 2025-11-05 09:10:47,916 [INFO] Best hyperparameters: {'model__learning_rate': 0.05, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 500, 'model__subsample': 1.0}
# 2025-11-05 09:10:47,986 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:10:48,007 [INFO] Feature group 9: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur']
# 2025-11-05 09:23:08,342 [INFO] Best CV score: 0.9870770862800565
# 2025-11-05 09:23:08,343 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 0.6}
# 2025-11-05 09:23:08,371 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:23:08,373 [INFO] Feature group 10: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term']
# 2025-11-05 09:35:37,595 [INFO] Best CV score: 0.9881485148514851
# 2025-11-05 09:35:37,596 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 09:35:37,617 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 0.9999446657813192, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 09:35:37,624 [INFO] Feature group 11: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp']
# 2025-11-05 09:48:47,416 [INFO] Best CV score: 0.9900742574257425
# 2025-11-05 09:48:47,417 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 09:48:47,491 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9996126604692341, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 09:48:47,492 [INFO] Feature group 12: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term']
# 2025-11-05 10:02:03,649 [INFO] Best CV score: 0.9908571428571429
# 2025-11-05 10:02:03,650 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.6}
# 2025-11-05 10:02:03,770 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:02:03,771 [INFO] Feature group 13: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone']
# 2025-11-05 10:15:27,407 [INFO] Best CV score: 0.9914727722772276
# 2025-11-05 10:15:27,409 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 10:15:27,434 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 10:15:27,533 [INFO] Feature group 14: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term']
# 2025-11-05 10:28:57,245 [INFO] Best CV score: 0.9920742574257426
# 2025-11-05 10:28:57,246 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 10:28:57,263 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9998339973439575, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 10:28:57,307 [INFO] Feature group 15: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration']
# 2025-11-05 10:42:06,182 [INFO] Best CV score: 0.9934999999999998
# 2025-11-05 10:42:06,183 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 10:42:06,207 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9998893315626384, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 10:42:06,208 [INFO] Feature group 16: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur']
# 2025-11-05 10:52:24,487 [INFO] Best CV score: 0.9909427157001414
# 2025-11-05 10:52:24,490 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 5, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 10:52:24,509 [INFO] Other scores: {'f1': 0.9577464788732395, 'roc_auc': 0.9998893315626384, 'precision': 0.9714285714285714, 'accuracy': 0.9944237918215614, 'balanced_accuracy': 0.9712262062859672, 'recall': 0.9444444444444444}
# 2025-11-05 10:52:24,510 [INFO] Feature group 17: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min']
# 2025-11-05 11:03:00,525 [INFO] Best CV score: 0.9895611739745404
# 2025-11-05 11:03:00,526 [INFO] Best hyperparameters: {'model__learning_rate': 0.05, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 11:03:00,545 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:03:00,547 [INFO] Feature group 18: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term']
# 2025-11-05 11:13:41,699 [INFO] Best CV score: 0.9906927157001414
# 2025-11-05 11:13:41,701 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 11:13:41,722 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9999446657813191, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 11:13:41,722 [INFO] Feature group 19: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur']
# 2025-11-05 11:24:35,443 [INFO] Best CV score: 0.9921099717114569
# 2025-11-05 11:24:35,451 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 4, 'model__min_samples_split': 2, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 11:24:35,466 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9998893315626384, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 11:24:35,467 [INFO] Feature group 20: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term']
# 2025-11-05 11:35:28,665 [INFO] Best CV score: 0.9942499999999999
# 2025-11-05 11:35:28,666 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 11:35:28,684 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 0.9998893315626384, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 11:35:28,685 [INFO] Feature group 21: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone']
# 2025-11-05 11:46:30,286 [INFO] Best CV score: 0.9936785714285714
# 2025-11-05 11:46:30,286 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 1.0}
# 2025-11-05 11:46:30,314 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:46:30,330 [INFO] Feature group 22: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN']
# 2025-11-05 11:55:13,257 [INFO] Best CV score: 0.9941785714285715
# 2025-11-05 11:55:13,258 [INFO] Best hyperparameters: {'model__learning_rate': 0.05, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 11:55:13,279 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 11:55:13,280 [INFO] Feature group 23: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term']
# 2025-11-05 12:00:38,272 [INFO] Best CV score: 0.9938656294200848
# 2025-11-05 12:00:38,273 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 12:00:38,295 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 12:00:38,298 [INFO] Feature group 24: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity']
# 2025-11-05 12:06:42,827 [INFO] Best CV score: 0.9936485148514851
# 2025-11-05 12:06:42,828 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 12:06:42,844 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:06:42,845 [INFO] Feature group 25: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term']
# 2025-11-05 12:12:28,899 [INFO] Best CV score: 0.9928327439886846
# 2025-11-05 12:12:28,900 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 12:12:28,933 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 12:12:28,942 [INFO] Feature group 26: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term']
# 2025-11-05 12:18:36,694 [INFO] Best CV score: 0.9926814002828855
# 2025-11-05 12:18:36,695 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 200, 'model__subsample': 1.0}
# 2025-11-05 12:18:36,718 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:18:36,718 [INFO] Feature group 27: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term']
# 2025-11-05 12:24:11,978 [INFO] Best CV score: 0.9931955445544555
# 2025-11-05 12:24:11,979 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.6}
# 2025-11-05 12:24:12,001 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:24:12,002 [INFO] Feature group 28: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term']
# 2025-11-05 12:30:28,256 [INFO] Best CV score: 0.9922556577086279
# 2025-11-05 12:30:28,257 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 0.8}
# 2025-11-05 12:30:28,280 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:30:28,281 [INFO] Feature group 29: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term']
# 2025-11-05 12:36:22,848 [INFO] Best CV score: 0.9920470297029702
# 2025-11-05 12:36:22,848 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'log2', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 12:36:22,865 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 12:36:22,865 [INFO] Feature group 30: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term']
# 2025-11-05 12:42:51,488 [INFO] Best CV score: 0.9927970297029702
# 2025-11-05 12:42:51,488 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 1.0}
# 2025-11-05 12:42:51,508 [INFO] Other scores: {'f1': 0.9714285714285714, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9962825278810409, 'balanced_accuracy': 0.9722222222222222, 'recall': 0.9444444444444444}
# 2025-11-05 12:42:51,508 [INFO] Feature group 31: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term']
# 2025-11-05 12:48:55,270 [INFO] Best CV score: 0.9931898868458274
# 2025-11-05 12:48:55,271 [INFO] Best hyperparameters: {'model__learning_rate': 0.1, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 12:48:55,287 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:48:55,288 [INFO] Feature group 32: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term', 'Gravida']
# 2025-11-05 12:55:27,868 [INFO] Best CV score: 0.9920413719943422
# 2025-11-05 12:55:27,868 [INFO] Best hyperparameters: {'model__learning_rate': 0.01, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200, 'model__subsample': 1.0}
# 2025-11-05 12:55:27,889 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 12:55:27,890 [INFO] Feature group 33: ['BW', 'GA', 'RespSpt_HFNCDone', 'RespSpt_HFOVDur', 'RespSpt_HFOVDone', 'Apgar1Min', 'MotherAge', 'RespSpt_NitrixOxideDone', 'RespSpt_NitrixOxideDur', 'PtRace_term', 'BirthAdmissionTemp', 'Surfactant_term', 'RespSpt_CPAPDone', 'Sex_term', 'SurfactantDuration', 'RespSpt_CPAPDur', 'Apgar5Min', 'BirthMultiplicity_term', 'RespSpt_ConvVentDur', 'InitResus_ETV_term', 'RespSpt_ConvVentDone', 'TPN', 'InitResus_O2_term', 'Parity', 'BirthGrowthStatus_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'AtSteroid Dose_term', 'InitResus_BMV_term', 'MaternalAnemia_term', 'Gravida', 'BirthFinalModeDeliver_term']
# 2025-11-05 13:02:04,176 [INFO] Best CV score: 0.9913684582743988
# 2025-11-05 13:02:04,176 [INFO] Best hyperparameters: {'model__learning_rate': 0.05, 'model__max_depth': 7, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 100, 'model__subsample': 0.8}
# 2025-11-05 13:02:04,191 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
