# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import pydot

from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn.metrics import make_scorer, f1_score, roc_auc_score, precision_score, balanced_accuracy_score, accuracy_score, recall_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE, RFECV

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from catboost import CatBoostClassifier

from collections import deque

# %%
import logging
import sys
from datetime import datetime

# Configure logging
log_filename = f"training_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.FileHandler(log_filename),
        logging.StreamHandler(sys.stdout)  # optional: show logs live in notebook
    ]
)

logger = logging.getLogger(__name__)
logger.info("==== Test logging setup ====")
# Out:
# 2025-11-05 07:42:00,544 [INFO] ==== Test logging setup ====

# %%
# define constants according to your dataset

DATASET = "sample.csv"
COLUMN_NAME_LOS = "DurationHospStayDay"
COLUMN_NAME_ADMISSION_DATE = "DateAdmission"
COLUMN_NAME_TARGET = "Outcome"

# %%
df = pd.read_csv('../../../../data/' + DATASET, low_memory=False)
df = df.drop(columns=[COLUMN_NAME_LOS])
df.drop(COLUMN_NAME_ADMISSION_DATE, axis=1, inplace=True)

# %%
# Example: binary outcome
X = df.drop(COLUMN_NAME_TARGET, axis=1)
y = df[COLUMN_NAME_TARGET]

# %%
label_encoder = LabelEncoder()
label_mapping = {}
for column in X.columns:
  if X[column].dtype == 'object':
    X[column] = X[column].astype(str)
    X[column] = label_encoder.fit_transform(X[column])
    label_mapping[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

logger.info(label_mapping.keys())
# Out:
# 2025-11-05 07:42:00,639 [INFO] dict_keys(['PtRace_term', 'MaternalDM_term', 'MaternalHT_term', 'MaternalEclampsia_term', 'MaternalChorAm_term', 'MaternalAnemia_term', 'MaternalAbPlacenta_term', 'MaternalBleedPlacenta_term', 'MaternalCordProlapse_term', 'AtSteroid_term', 'Intrapartum Antibiotic_term', 'BirthGrowthStatus_term', 'Sex_term', 'BirthFinalModeDeliver_term', 'InitResus_CC_term', 'InitResus_BMV_term', 'InitResus_O2_term', 'InitResus_CPAP_term', 'InitResus_Adren_term', 'InitResus_ETV_term', 'RespSpt_HFOVDone', 'RespSpt_ConvVentDone', 'RespSpt_NitrixOxideDone', 'RespSpt_CPAPDone', 'RespSpt_HFNCDone', 'RespSpt_term', 'Surfactant_term', 'SurfactantDuration', 'TPN'])

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=123
)

# %% [markdown]
# ## Scoring

# %%
scoring = {
    "f1": make_scorer(f1_score, average="binary", pos_label="Dead"),
    "roc_auc": make_scorer(roc_auc_score, needs_proba=True),
    "precision": make_scorer(precision_score, pos_label="Dead"),
    "accuracy": make_scorer(accuracy_score),
    "balanced_accuracy": make_scorer(balanced_accuracy_score),
    "recall": make_scorer(recall_score, pos_label="Dead")
}

# %%
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    res = {
        "f1" : f1_score(y_test, y_pred, average="binary", pos_label="Dead"),
        "roc_auc" : roc_auc_score(y_test, y_pred_proba),
        "precision" : precision_score(y_test, y_pred, pos_label="Dead"),
        "accuracy" : accuracy_score(y_test, y_pred),
        "balanced_accuracy" : balanced_accuracy_score(y_test, y_pred),
        "recall" : recall_score(y_test, y_pred, pos_label="Dead")
    }
    return res

# %% [markdown]
# ## Models

# %%
models = [{
        "model": LogisticRegression(max_iter=3000),
        "model_name": "Logistic Regression",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],   # regularization strength
            "model__penalty": ["l1", "l2", "elasticnet"],
            "model__l1_ratio": [0, 0.5, 1]         # only used if elasticnet
        }
    },
    {
        "model": GaussianNB(),
        "model_name": "Gaussian Naive Bayes",
        "hyperparameters": {
            "model__var_smoothing": [1e-9, 1e-8, 1e-7, 1e-6]   # handles numerical stability
        }
    },
    {
        "model": DecisionTreeClassifier(),
        "model_name": "Decision Tree Classifier",
        "hyperparameters": {
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 5, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": [None, "sqrt", "log2"]
        }
    },
    {
        "model": RandomForestClassifier(),
        "model_name": "Random Forest Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": SVC(probability=True),
        "model_name": "Support Vector Classifier",
        "hyperparameters": {
            "model__C": [0.01, 0.1, 1, 10, 100],
            "model__kernel": ["linear", "rbf", "poly"],
            "model__degree": [2, 3, 4],   # only for poly
            "model__gamma": ["scale", "auto"]
        }
    },
    {
        "model": ExtraTreesClassifier(criterion="entropy",random_state=123),
        "model_name": "Extra Trees Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__criterion": ["gini", "entropy", "log_loss"],
            "model__max_depth": [None, 10, 20, 50],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": KNeighborsClassifier(n_neighbors=3,metric='minkowski',p=2),
        "model_name": "K-Neighbors Classifier",
        "hyperparameters": {
            "model__n_neighbors": [3, 5, 7, 11],
            "model__weights": ["uniform", "distance"],
            "model__metric": ["minkowski", "manhattan"],
            "model__p": [1, 2]   # 1=Manhattan, 2=Euclidean
        }
    },
    {
        "model": GradientBoostingClassifier(),
        "model_name": "Gradient Boosting Classifier",
        "hyperparameters": {
            "model__n_estimators": [100, 200, 500],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__max_depth": [3, 5, 7],
            "model__min_samples_split": [2, 5, 10],
            "model__min_samples_leaf": [1, 2, 4],
            "model__subsample": [0.6, 0.8, 1.0],
            "model__max_features": ["sqrt", "log2", None]
        }
    },
    {
        "model": CatBoostClassifier(verbose=False),
        "model_name": "CatBoost Classifier",
        "hyperparameters": {
            "model__iterations": [200, 500, 1000],
            "model__learning_rate": [0.01, 0.05, 0.1],
            "model__depth": [4, 6, 8, 10],
            "model__l2_leaf_reg": [1, 3, 5, 7]
        }
    }]

# %% [markdown]
# ## Tree Processing

# %%
def getRealNodes(nodes):
    real_nodes = []
    for node in nodes:
        if node.get_attributes().get("label") is not None:
            real_nodes.append(node)
    return real_nodes

# %%
def jsonify_nodes(root_node_name, node_list, edge_list):
    """
    Traverses a pydot graph from a root node and returns a list of dictionaries 
    with each node's label and level.

    Args:
        root_node_name (str): The name of the starting (root) node.
        node_list (list): A list of pydot Node objects.
        edge_list (list): A list of pydot Edge objects.

    Returns:
        list: A list of dictionaries, each containing a node's 'label' and 'level'.
    """
    # 1. Build an adjacency list for efficient neighbor lookup
    adj = {node.get_name(): [] for node in node_list}
    for edge in edge_list:
        source = edge.get_source()
        destination = edge.get_destination()
        if source in adj:
            adj[source].append(destination)
    
    # 2. Map node names to their labels
    # Use .get_label() but handle the case where it returns a name, which occurs
    # if no explicit label is set.
    name_to_label_map = {
        node.get_name(): node.get_attributes().get("label")
        if node.get_label() != node.get_name() else node.get_name()
        for node in node_list
    }

    # 3. Prepare data structures for BFS
    queue = deque([(root_node_name, 0)])  # Store tuples of (node_name, level)
    visited = {root_node_name}
    result_list = []

    # 4. Perform the BFS traversal
    while queue:
        current_node_name, level = queue.popleft()
        
        # Get the label from the map we created
        current_label = name_to_label_map.get(current_node_name, current_node_name)
        
        # Add the current node's label and level to the result
        result_list.append({
            "label": current_label,
            "level": level
        })

        # Enqueue all unvisited neighbors
        for neighbor_name in adj.get(current_node_name, []):
            if neighbor_name not in visited:
                visited.add(neighbor_name)
                queue.append((neighbor_name, level + 1))
    
    return result_list

# %%
def tabulate_nodes(json_nodes):
    for node in json_nodes:
        node['label'] = node['label'].split(" ")[0].replace('"', '')
        
    return pd.DataFrame(json_nodes)

test_list = [{
    "label": "BW <= ashdjkasdhk"
}]

tabulate_nodes(test_list)
# Out:
#   label
# 0    BW

# %%
def compute_rankings(tree_count):
    df_list = []
    for i in range(tree_count):
        graph = pydot.graph_from_dot_file(f'Decision paths for Tree {i+1}.dot')
        real_nodes = getRealNodes(graph[0].get_nodes())
        jsonified_nodes = jsonify_nodes(real_nodes[0].get_name(), graph[0].get_nodes(), graph[0].get_edges())
        df_list.append(tabulate_nodes(jsonified_nodes))
        
    aggregated_df = pd.concat(df_list, ignore_index=True)
    return aggregated_df

# %%
def count_by_label(aggregated_df):
    label_counts = (
        aggregated_df
        .groupby(['level', 'label'])
        .size()
        .reset_index(name='count')
        .sort_values(by=['level', 'count'], ascending=[True, False])
    )
    return label_counts

# %%
def getScore(levels:pd.Series):
    max_level = levels.max()
    logger.info(f"Max level: {max_level}")
    scores = []
    for level in levels:
        # The lower the level, the higher the score
        scores.append(max_level - level)
    return scores

# %%
def label_counts_with_score(label_counts):
    label_counts_with_score_df = label_counts.copy()
    label_counts_with_score_df['score'] = (label_counts_with_score_df['count'] * getScore(label_counts_with_score_df['level']))
    label_counts_with_score_df = label_counts_with_score_df.drop(columns=['count', 'level'])
    label_counts_with_score_df = label_counts_with_score_df.groupby(['label'])['score'].sum().reset_index()
    label_counts_with_score_df = label_counts_with_score_df.sort_values(by=['score'], ascending=False)
    return label_counts_with_score_df

# %% [markdown]
# ## Feature name correction

# %%
def rectify_feature_names(ranked_features):
    for i, feature in enumerate(ranked_features):
        if feature == "AtSteroid":
            ranked_features[i] = "AtSteroid Dose_term"
        if feature == "Intrapartum":
            ranked_features[i] = "Intrapartum Antibiotic_term"
    ranked_features.remove("entropy")
    return ranked_features

# %% [markdown]
# ## Modeling

# %%
base_estimator = ExtraTreesClassifier(criterion="entropy",random_state=123)
base_estimator.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(criterion='entropy', random_state=123)

# %%
for i, tree in enumerate(base_estimator.estimators_):
    # In GradientBoostingClassifier, estimators_ is a 2D array where each row
    # represents a stage and each column represents a class (for multi-class)
    # For binary classification, there is only one tree per stage.

    # You can use export_text to get a text-based representation of the tree rules
    tree_rules = export_graphviz(tree, out_file=f'Decision paths for Tree {i+1}.dot', feature_names=X_train.columns, class_names=base_estimator.classes_, filled=True)

# %%
aggregated_df = compute_rankings(tree_count=100)
aggregated_df
# Out:
#                      label  level
# 0     RespSpt_ConvVentDone      0
# 1                Apgar1Min      1
# 2         RespSpt_CPAPDone      1
# 3                  entropy      2
# 4          RespSpt_HFOVDur      2
# ...                    ...    ...
# 8617               entropy     12
# 8618               entropy     12
# 8619                    BW     12
# 8620               entropy     13
# 8621               entropy     13
#
# [8622 rows x 2 columns]

# %%
count_by_label_df = count_by_label(aggregated_df)
label_counts_with_score_df = label_counts_with_score(count_by_label_df)
label_counts_with_score_df
# Out:
# 2025-11-05 07:43:05,478 [INFO] Max level: 17
#                          label  score
# 43                     entropy  42409
# 9                           GA   2615
# 33            RespSpt_HFNCDone   2420
# 4                           BW   2263
# 0                    Apgar1Min   2015
# 34            RespSpt_HFOVDone   1829
# 14         InitResus_CPAP_term   1731
# 7       BirthGrowthStatus_term   1714
# 32         RespSpt_ConvVentDur   1714
# 29            RespSpt_CPAPDone   1684
# 41             Surfactant_term   1655
# 15          InitResus_ETV_term   1645
# 30             RespSpt_CPAPDur   1634
# 39                    Sex_term   1620
# 35             RespSpt_HFOVDur   1604
# 26                   MotherAge   1555
# 1                    Apgar5Min   1479
# 31        RespSpt_ConvVentDone   1469
# 28                 PtRace_term   1451
# 27                      Parity   1423
# 5           BirthAdmissionTemp   1371
# 10                     Gravida   1155
# 40          SurfactantDuration   1149
# 6   BirthFinalModeDeliver_term   1084
# 3               AtSteroid_term   1004
# 12          InitResus_BMV_term    943
# 2                    AtSteroid    894
# 42                         TPN    877
# 23             MaternalDM_term    874
# 16           InitResus_O2_term    853
# 37      RespSpt_NitrixOxideDur    848
# 36     RespSpt_NitrixOxideDone    788
# 19         MaternalAnemia_term    693
# 8       BirthMultiplicity_term    684
# 17                 Intrapartum    529
# 24      MaternalEclampsia_term    453
# 25             MaternalHT_term    340
# 38                RespSpt_term    321
# 22   MaternalCordProlapse_term    228
# 20  MaternalBleedPlacenta_term    194
# 11        InitResus_Adren_term    170
# 13           InitResus_CC_term    130
# 21         MaternalChorAm_term     91
# 18     MaternalAbPlacenta_term     38

# %%
ranked_features = label_counts_with_score_df['label'].tolist()
ranked_features = rectify_feature_names(ranked_features)

# %%
feature_group_list = []

for i, feature in enumerate(ranked_features):
    feature_group_list.append(ranked_features[:i+1])

for i, items in enumerate(feature_group_list):
    logger.info(f"Feature Group {i+1}: {items}")
# Out:
# 2025-11-05 07:43:05,496 [INFO] Feature Group 1: ['GA']
# 2025-11-05 07:43:05,497 [INFO] Feature Group 2: ['GA', 'RespSpt_HFNCDone']
# 2025-11-05 07:43:05,497 [INFO] Feature Group 3: ['GA', 'RespSpt_HFNCDone', 'BW']
# 2025-11-05 07:43:05,499 [INFO] Feature Group 4: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min']
# 2025-11-05 07:43:05,501 [INFO] Feature Group 5: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone']
# 2025-11-05 07:43:05,502 [INFO] Feature Group 6: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term']
# 2025-11-05 07:43:05,502 [INFO] Feature Group 7: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term']
# 2025-11-05 07:43:05,503 [INFO] Feature Group 8: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur']
# 2025-11-05 07:43:05,503 [INFO] Feature Group 9: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone']
# 2025-11-05 07:43:05,505 [INFO] Feature Group 10: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term']
# 2025-11-05 07:43:05,506 [INFO] Feature Group 11: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term']
# 2025-11-05 07:43:05,506 [INFO] Feature Group 12: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur']
# 2025-11-05 07:43:05,508 [INFO] Feature Group 13: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term']
# 2025-11-05 07:43:05,508 [INFO] Feature Group 14: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur']
# 2025-11-05 07:43:05,508 [INFO] Feature Group 15: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge']
# 2025-11-05 07:43:05,509 [INFO] Feature Group 16: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min']
# 2025-11-05 07:43:05,510 [INFO] Feature Group 17: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone']
# 2025-11-05 07:43:05,556 [INFO] Feature Group 18: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term']
# 2025-11-05 07:43:05,580 [INFO] Feature Group 19: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity']
# 2025-11-05 07:43:05,590 [INFO] Feature Group 20: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp']
# 2025-11-05 07:43:05,591 [INFO] Feature Group 21: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida']
# 2025-11-05 07:43:05,592 [INFO] Feature Group 22: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration']
# 2025-11-05 07:43:05,592 [INFO] Feature Group 23: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term']
# 2025-11-05 07:43:05,594 [INFO] Feature Group 24: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term']
# 2025-11-05 07:43:05,594 [INFO] Feature Group 25: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term']
# 2025-11-05 07:43:05,594 [INFO] Feature Group 26: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term']
# 2025-11-05 07:43:05,594 [INFO] Feature Group 27: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN']
# 2025-11-05 07:43:05,595 [INFO] Feature Group 28: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term']
# 2025-11-05 07:43:05,596 [INFO] Feature Group 29: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term']
# 2025-11-05 07:43:05,600 [INFO] Feature Group 30: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur']
# 2025-11-05 07:43:05,601 [INFO] Feature Group 31: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone']
# 2025-11-05 07:43:05,602 [INFO] Feature Group 32: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term']
# 2025-11-05 07:43:05,602 [INFO] Feature Group 33: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term']
# 2025-11-05 07:43:05,602 [INFO] Feature Group 34: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term']
# 2025-11-05 07:43:05,603 [INFO] Feature Group 35: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term']
# 2025-11-05 07:43:05,603 [INFO] Feature Group 36: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term']
# 2025-11-05 07:43:05,603 [INFO] Feature Group 37: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term']
# 2025-11-05 07:43:05,604 [INFO] Feature Group 38: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term']
# 2025-11-05 07:43:05,604 [INFO] Feature Group 39: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term']
# 2025-11-05 07:43:05,606 [INFO] Feature Group 40: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term']
# 2025-11-05 07:43:05,607 [INFO] Feature Group 41: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term']
# 2025-11-05 07:43:05,608 [INFO] Feature Group 42: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'MaternalChorAm_term']
# 2025-11-05 07:43:05,608 [INFO] Feature Group 43: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'MaternalChorAm_term', 'MaternalAbPlacenta_term']

# %%
base_estimator = ExtraTreesClassifier()


# Full pipeline: Feature selection + Oversampling + Classifier
pipeline = ImbPipeline([
    ("ros", SMOTE(random_state=123)),
    ("model", base_estimator)
])

# Hyperparameter grid
param_grid = {
    "model__n_estimators": [100, 200, 500],
    "model__criterion": ["gini", "entropy", "log_loss"],
    "model__max_depth": [None, 10, 20, 50],
    "model__min_samples_split": [2, 5, 10],
    "model__min_samples_leaf": [1, 2, 4],
    "model__max_features": ["sqrt", "log2", None]
}

# Outer CV (for tuning)
outer_cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)

# Define scoring
scorer = make_scorer(roc_auc_score, needs_proba=True)

for i, item in enumerate(feature_group_list):
    logger.info(f"Feature group {i+1}: {item}")
    # Randomized search
    search = GridSearchCV(
        estimator=pipeline,
        param_grid=param_grid,
        cv=outer_cv,
        scoring=scorer,
        n_jobs=-1,
        verbose=0
    )

    search.fit(X_train[item], y_train)

    logger.info(f"Best CV score: {search.best_score_}")
    logger.info(f"Best hyperparameters: {search.best_params_}")
    logger.info(f"Other scores: {evaluate_model(search.best_estimator_, X_train[item], y_train)}")
# Out:
# 2025-11-05 07:43:05,615 [INFO] Feature group 1: ['GA']
# 2025-11-05 07:46:39,701 [INFO] Best CV score: 0.7893748231966053
# 2025-11-05 07:46:39,703 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 4, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 07:46:39,735 [INFO] Other scores: {'f1': 0.35658914728682173, 'roc_auc': 0.8437638335546702, 'precision': 0.24731182795698925, 'accuracy': 0.845724907063197, 'balanced_accuracy': 0.7497233289065959, 'recall': 0.6388888888888888}
# 2025-11-05 07:46:39,780 [INFO] Feature group 2: ['GA', 'RespSpt_HFNCDone']
# 2025-11-05 07:51:02,984 [INFO] Best CV score: 0.8983102899575671
# 2025-11-05 07:51:02,986 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 07:51:03,075 [INFO] Other scores: {'f1': 0.7199999999999999, 'roc_auc': 0.9357569721115538, 'precision': 0.6923076923076923, 'accuracy': 0.9609665427509294, 'balanced_accuracy': 0.8630478087649402, 'recall': 0.75}
# 2025-11-05 07:51:03,090 [INFO] Feature group 3: ['GA', 'RespSpt_HFNCDone', 'BW']
# 2025-11-05 07:54:59,232 [INFO] Best CV score: 0.9486789250353607
# 2025-11-05 07:54:59,233 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 07:54:59,462 [INFO] Other scores: {'f1': 0.918918918918919, 'roc_auc': 0.9983953076582559, 'precision': 0.8947368421052632, 'accuracy': 0.9888475836431226, 'balanced_accuracy': 0.9682381584772023, 'recall': 0.9444444444444444}
# 2025-11-05 07:54:59,463 [INFO] Feature group 4: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min']
# 2025-11-05 07:58:32,176 [INFO] Best CV score: 0.9412892503536068
# 2025-11-05 07:58:32,177 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 07:58:32,206 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 07:58:32,208 [INFO] Feature group 5: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone']
# 2025-11-05 08:01:29,536 [INFO] Best CV score: 0.9757682107496464
# 2025-11-05 08:01:29,537 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:01:29,566 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:01:29,566 [INFO] Feature group 6: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term']
# 2025-11-05 08:04:20,180 [INFO] Best CV score: 0.9658794200848655
# 2025-11-05 08:04:20,181 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:04:20,207 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:04:20,208 [INFO] Feature group 7: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term']
# 2025-11-05 08:07:13,049 [INFO] Best CV score: 0.9638242574257425
# 2025-11-05 08:07:13,050 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:07:13,076 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:07:13,077 [INFO] Feature group 8: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur']
# 2025-11-05 08:10:14,089 [INFO] Best CV score: 0.9779011669024046
# 2025-11-05 08:10:14,090 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:10:14,115 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:10:14,116 [INFO] Feature group 9: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone']
# 2025-11-05 08:13:14,250 [INFO] Best CV score: 0.976124469589816
# 2025-11-05 08:13:14,252 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 08:13:14,372 [INFO] Other scores: {'f1': 0.9459459459459458, 'roc_auc': 0.9997786631252767, 'precision': 0.9210526315789473, 'accuracy': 0.9925650557620818, 'balanced_accuracy': 0.9831230633023462, 'recall': 0.9722222222222222}
# 2025-11-05 08:13:14,398 [INFO] Feature group 10: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term']
# 2025-11-05 08:16:19,632 [INFO] Best CV score: 0.9830424328147099
# 2025-11-05 08:16:19,632 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:16:19,700 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:16:19,705 [INFO] Feature group 11: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term']
# 2025-11-05 08:20:21,707 [INFO] Best CV score: 0.987025459688826
# 2025-11-05 08:20:21,709 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:20:21,763 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:20:21,781 [INFO] Feature group 12: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur']
# 2025-11-05 08:24:13,963 [INFO] Best CV score: 0.9858633309759547
# 2025-11-05 08:24:13,964 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:24:13,989 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:24:14,026 [INFO] Feature group 13: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term']
# 2025-11-05 08:28:06,975 [INFO] Best CV score: 0.9856039603960396
# 2025-11-05 08:28:06,976 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:28:07,002 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:28:07,014 [INFO] Feature group 14: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur']
# 2025-11-05 08:31:56,945 [INFO] Best CV score: 0.9862284299858558
# 2025-11-05 08:31:56,947 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 08:31:57,033 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:31:57,052 [INFO] Feature group 15: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge']
# 2025-11-05 08:35:46,014 [INFO] Best CV score: 0.9852998585572843
# 2025-11-05 08:35:46,016 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 08:35:46,100 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:35:46,118 [INFO] Feature group 16: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min']
# 2025-11-05 08:39:44,357 [INFO] Best CV score: 0.986275459688826
# 2025-11-05 08:39:44,358 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# 2025-11-05 08:39:44,422 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 08:39:44,449 [INFO] Feature group 17: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone']
# 2025-11-05 08:43:42,981 [INFO] Best CV score: 0.9856212871287129
# 2025-11-05 08:43:42,982 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 500}
# 2025-11-05 08:43:43,210 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:43:43,213 [INFO] Feature group 18: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term']
# 2025-11-05 08:47:42,381 [INFO] Best CV score: 0.9888628005657709
# 2025-11-05 08:47:42,382 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 08:47:42,409 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:47:42,410 [INFO] Feature group 19: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity']
# 2025-11-05 08:51:44,932 [INFO] Best CV score: 0.9885592291371994
# 2025-11-05 08:51:44,934 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 10, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:51:44,963 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:51:45,002 [INFO] Feature group 20: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp']
# 2025-11-05 08:55:50,023 [INFO] Best CV score: 0.9895427864214993
# 2025-11-05 08:55:50,024 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 200}
# 2025-11-05 08:55:50,057 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:55:50,078 [INFO] Feature group 21: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida']
# 2025-11-05 08:59:50,714 [INFO] Best CV score: 0.9889492574257426
# 2025-11-05 08:59:50,716 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 08:59:50,793 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 08:59:50,795 [INFO] Feature group 22: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration']
# 2025-11-05 09:04:04,752 [INFO] Best CV score: 0.9884055869872702
# 2025-11-05 09:04:04,755 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 500}
# 2025-11-05 09:04:04,990 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:04:05,006 [INFO] Feature group 23: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term']
# 2025-11-05 09:08:12,727 [INFO] Best CV score: 0.9876842291371994
# 2025-11-05 09:08:12,729 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:08:12,754 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:08:12,785 [INFO] Feature group 24: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term']
# 2025-11-05 09:12:33,616 [INFO] Best CV score: 0.9873778288543141
# 2025-11-05 09:12:33,618 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:12:33,640 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:12:33,641 [INFO] Feature group 25: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term']
# 2025-11-05 09:16:48,724 [INFO] Best CV score: 0.9870733734087695
# 2025-11-05 09:16:48,725 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:16:48,748 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:16:48,762 [INFO] Feature group 26: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term']
# 2025-11-05 09:21:22,773 [INFO] Best CV score: 0.9860526874115983
# 2025-11-05 09:21:22,775 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:21:22,801 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:21:22,819 [INFO] Feature group 27: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN']
# 2025-11-05 09:25:43,683 [INFO] Best CV score: 0.9865770862800567
# 2025-11-05 09:25:43,684 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:25:43,710 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:25:43,725 [INFO] Feature group 28: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term']
# 2025-11-05 09:30:21,708 [INFO] Best CV score: 0.9838525459688826
# 2025-11-05 09:30:21,710 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 200}
# 2025-11-05 09:30:21,812 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:30:21,813 [INFO] Feature group 29: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term']
# 2025-11-05 09:34:58,266 [INFO] Best CV score: 0.9860555162659124
# 2025-11-05 09:34:58,267 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': None, 'model__min_samples_leaf': 2, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 09:34:58,397 [INFO] Other scores: {'f1': 0.9859154929577464, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 0.9981412639405205, 'balanced_accuracy': 0.9861111111111112, 'recall': 0.9722222222222222}
# 2025-11-05 09:34:58,398 [INFO] Feature group 30: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur']
# 2025-11-05 09:39:24,691 [INFO] Best CV score: 0.9867604314002829
# 2025-11-05 09:39:24,692 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:39:24,720 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:39:24,720 [INFO] Feature group 31: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone']
# 2025-11-05 09:44:05,410 [INFO] Best CV score: 0.9887970297029703
# 2025-11-05 09:44:05,412 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 09:44:05,442 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:44:05,443 [INFO] Feature group 32: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term']
# 2025-11-05 09:48:32,839 [INFO] Best CV score: 0.9883111739745403
# 2025-11-05 09:48:32,840 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# 2025-11-05 09:48:32,865 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:48:32,866 [INFO] Feature group 33: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term']
# 2025-11-05 09:53:12,552 [INFO] Best CV score: 0.9878520155586987
# 2025-11-05 09:53:12,554 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:53:12,601 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:53:12,602 [INFO] Feature group 34: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term']
# 2025-11-05 09:57:55,050 [INFO] Best CV score: 0.9879568599717115
# 2025-11-05 09:57:55,051 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 09:57:55,080 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 09:57:55,081 [INFO] Feature group 35: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term']
# 2025-11-05 10:02:28,008 [INFO] Best CV score: 0.9880884016973125
# 2025-11-05 10:02:28,010 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# 2025-11-05 10:02:28,071 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:02:28,109 [INFO] Feature group 36: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term']
# 2025-11-05 10:07:16,070 [INFO] Best CV score: 0.9878412305516268
# 2025-11-05 10:07:16,071 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:07:16,096 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:07:16,097 [INFO] Feature group 37: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term']
# 2025-11-05 10:12:09,212 [INFO] Best CV score: 0.9902425742574259
# 2025-11-05 10:12:09,214 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': None, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 10:12:09,334 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:12:09,335 [INFO] Feature group 38: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term']
# 2025-11-05 10:16:47,536 [INFO] Best CV score: 0.9888468882602547
# 2025-11-05 10:16:47,537 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 50, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 100}
# 2025-11-05 10:16:47,560 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:16:47,561 [INFO] Feature group 39: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term']
# 2025-11-05 10:21:38,107 [INFO] Best CV score: 0.9884897454031117
# 2025-11-05 10:21:38,108 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 10:21:38,169 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:21:38,170 [INFO] Feature group 40: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term']
# 2025-11-05 10:26:30,983 [INFO] Best CV score: 0.9875169731258839
# 2025-11-05 10:26:30,984 [INFO] Best hyperparameters: {'model__criterion': 'log_loss', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 10:26:31,011 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:26:31,022 [INFO] Feature group 41: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term']
# 2025-11-05 10:31:10,532 [INFO] Best CV score: 0.9880555162659123
# 2025-11-05 10:31:10,534 [INFO] Best hyperparameters: {'model__criterion': 'gini', 'model__max_depth': 10, 'model__max_features': 'log2', 'model__min_samples_leaf': 1, 'model__min_samples_split': 5, 'model__n_estimators': 200}
# 2025-11-05 10:31:10,568 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:31:10,622 [INFO] Feature group 42: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'MaternalChorAm_term']
# 2025-11-05 10:36:06,096 [INFO] Best CV score: 0.9879211456859972
# 2025-11-05 10:36:06,097 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 2, 'model__min_samples_split': 10, 'model__n_estimators': 100}
# 2025-11-05 10:36:06,161 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
# 2025-11-05 10:36:06,162 [INFO] Feature group 43: ['GA', 'RespSpt_HFNCDone', 'BW', 'Apgar1Min', 'RespSpt_HFOVDone', 'InitResus_CPAP_term', 'BirthGrowthStatus_term', 'RespSpt_ConvVentDur', 'RespSpt_CPAPDone', 'Surfactant_term', 'InitResus_ETV_term', 'RespSpt_CPAPDur', 'Sex_term', 'RespSpt_HFOVDur', 'MotherAge', 'Apgar5Min', 'RespSpt_ConvVentDone', 'PtRace_term', 'Parity', 'BirthAdmissionTemp', 'Gravida', 'SurfactantDuration', 'BirthFinalModeDeliver_term', 'AtSteroid_term', 'InitResus_BMV_term', 'AtSteroid Dose_term', 'TPN', 'MaternalDM_term', 'InitResus_O2_term', 'RespSpt_NitrixOxideDur', 'RespSpt_NitrixOxideDone', 'MaternalAnemia_term', 'BirthMultiplicity_term', 'Intrapartum Antibiotic_term', 'MaternalEclampsia_term', 'MaternalHT_term', 'RespSpt_term', 'MaternalCordProlapse_term', 'MaternalBleedPlacenta_term', 'InitResus_Adren_term', 'InitResus_CC_term', 'MaternalChorAm_term', 'MaternalAbPlacenta_term']
# 2025-11-05 10:41:02,440 [INFO] Best CV score: 0.9878177157001413
# 2025-11-05 10:41:02,441 [INFO] Best hyperparameters: {'model__criterion': 'entropy', 'model__max_depth': 20, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 1, 'model__min_samples_split': 2, 'model__n_estimators': 100}
# 2025-11-05 10:41:02,503 [INFO] Other scores: {'f1': 1.0, 'roc_auc': 1.0, 'precision': 1.0, 'accuracy': 1.0, 'balanced_accuracy': 1.0, 'recall': 1.0}
